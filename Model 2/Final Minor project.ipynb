# %% [markdown]
# ## Load our dataset
# #### Display some images from our dataset
# #### Dataset contain images from seven different Categories

# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "../input/face-expression-recognition-dataset/images/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train"):
    for i in range(1,3):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path 
                              + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Image augmentation using keras ImageDataGenerator

# %%
# building data generator 

from keras.preprocessing.image import ImageDataGenerator

batch_size = 128
base_path = "../input/face-expression-recognition-dataset/images/"


train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   rotation_range = 20,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale= 1.0/255)

train_generator = train_datagen.flow_from_directory(base_path + "train",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(base_path + "validation",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# # Defining our 4 Convolution and 2 Dense layers model

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, 
                            Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 7

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(56, 56,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

print(model.summary())

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 56, 56, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 56, 56, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 512)       590336
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________
# None

# %%
# %%time

# number of epochs to train the NN
epochs = 50

# checkpoint to save best model
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy',
                                             verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# Epoch 1/50
# 225/225 [==============================] - ETA: 0s - loss: 2.0617 - accuracy: 0.2196
# Epoch 00001: val_accuracy improved from -inf to 0.20014, saving model to model_weights.h5
# 225/225 [==============================] - 191s 848ms/step - loss: 2.0617 - accuracy: 0.2196 - val_loss: 1.8519 - val_accuracy: 0.2001
# Epoch 2/50
# 225/225 [==============================] - ETA: 0s - loss: 1.9205 - accuracy: 0.2397
# Epoch 00002: val_accuracy did not improve from 0.20014
# 225/225 [==============================] - 43s 189ms/step - loss: 1.9205 - accuracy: 0.2397 - val_loss: 1.8821 - val_accuracy: 0.1768
# Epoch 3/50
# 225/225 [==============================] - ETA: 0s - loss: 1.8658 - accuracy: 0.2627
# Epoch 00003: val_accuracy improved from 0.20014 to 0.29063, saving model to model_weights.h5
# 225/225 [==============================] - 45s 202ms/step - loss: 1.8658 - accuracy: 0.2627 - val_loss: 1.7573 - val_accuracy: 0.2906
# Epoch 4/50
# 225/225 [==============================] - ETA: 0s - loss: 1.8181 - accuracy: 0.2808
# Epoch 00004: val_accuracy improved from 0.29063 to 0.33920, saving model to model_weights.h5
# 225/225 [==============================] - 44s 196ms/step - loss: 1.8181 - accuracy: 0.2808 - val_loss: 1.6696 - val_accuracy: 0.3392
# Epoch 5/50
# 225/225 [==============================] - ETA: 0s - loss: 1.7653 - accuracy: 0.3062 ETA: 1s - loss: 1.765
# Epoch 00005: val_accuracy improved from 0.33920 to 0.35170, saving model to model_weights.h5
# 225/225 [==============================] - 43s 191ms/step - loss: 1.7653 - accuracy: 0.3062 - val_loss: 1.6851 - val_accuracy: 0.3517
# Epoch 6/50
# 225/225 [==============================] - ETA: 0s - loss: 1.7194 - accuracy: 0.3279
# Epoch 00006: val_accuracy did not improve from 0.35170
# 225/225 [==============================] - 45s 201ms/step - loss: 1.7194 - accuracy: 0.3279 - val_loss: 1.8729 - val_accuracy: 0.3399
# Epoch 7/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6637 - accuracy: 0.3492
# Epoch 00007: val_accuracy improved from 0.35170 to 0.40895, saving model to model_weights.h5
# 225/225 [==============================] - 89s 398ms/step - loss: 1.6637 - accuracy: 0.3492 - val_loss: 1.5523 - val_accuracy: 0.4089
# Epoch 8/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6384 - accuracy: 0.3609
# Epoch 00008: val_accuracy improved from 0.40895 to 0.41293, saving model to model_weights.h5
# 225/225 [==============================] - 42s 186ms/step - loss: 1.6384 - accuracy: 0.3609 - val_loss: 1.5444 - val_accuracy: 0.4129
# Epoch 9/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6006 - accuracy: 0.3773
# Epoch 00009: val_accuracy improved from 0.41293 to 0.41392, saving model to model_weights.h5
# 225/225 [==============================] - 43s 190ms/step - loss: 1.6006 - accuracy: 0.3773 - val_loss: 1.5905 - val_accuracy: 0.4139
# Epoch 10/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5647 - accuracy: 0.3926
# Epoch 00010: val_accuracy improved from 0.41392 to 0.44744, saving model to model_weights.h5
# 225/225 [==============================] - 45s 199ms/step - loss: 1.5647 - accuracy: 0.3926 - val_loss: 1.4726 - val_accuracy: 0.4474
# Epoch 11/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5335 - accuracy: 0.4072
# Epoch 00011: val_accuracy improved from 0.44744 to 0.45696, saving model to model_weights.h5
# 225/225 [==============================] - 45s 201ms/step - loss: 1.5335 - accuracy: 0.4072 - val_loss: 1.4352 - val_accuracy: 0.4570
# Epoch 12/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4997 - accuracy: 0.4160
# Epoch 00012: val_accuracy improved from 0.45696 to 0.48509, saving model to model_weights.h5
# 225/225 [==============================] - 43s 190ms/step - loss: 1.4997 - accuracy: 0.4160 - val_loss: 1.3566 - val_accuracy: 0.4851
# Epoch 13/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4757 - accuracy: 0.4307
# Epoch 00013: val_accuracy did not improve from 0.48509
# 225/225 [==============================] - 42s 185ms/step - loss: 1.4757 - accuracy: 0.4307 - val_loss: 1.4522 - val_accuracy: 0.4651
# Epoch 14/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4487 - accuracy: 0.4377
# Epoch 00014: val_accuracy improved from 0.48509 to 0.50043, saving model to model_weights.h5
# 225/225 [==============================] - 44s 193ms/step - loss: 1.4487 - accuracy: 0.4377 - val_loss: 1.3129 - val_accuracy: 0.5004
# Epoch 15/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4169 - accuracy: 0.4528
# Epoch 00015: val_accuracy did not improve from 0.50043
# 225/225 [==============================] - 46s 205ms/step - loss: 1.4169 - accuracy: 0.4528 - val_loss: 1.4485 - val_accuracy: 0.4766
# Epoch 16/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3933 - accuracy: 0.4651
# Epoch 00016: val_accuracy improved from 0.50043 to 0.51165, saving model to model_weights.h5
# 225/225 [==============================] - 42s 189ms/step - loss: 1.3933 - accuracy: 0.4651 - val_loss: 1.2813 - val_accuracy: 0.5116
# Epoch 17/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3724 - accuracy: 0.4723
# Epoch 00017: val_accuracy did not improve from 0.51165
# 225/225 [==============================] - 42s 186ms/step - loss: 1.3724 - accuracy: 0.4723 - val_loss: 1.3750 - val_accuracy: 0.4936
# Epoch 18/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3499 - accuracy: 0.4823
# Epoch 00018: val_accuracy improved from 0.51165 to 0.54531, saving model to model_weights.h5
# 225/225 [==============================] - 46s 205ms/step - loss: 1.3499 - accuracy: 0.4823 - val_loss: 1.2150 - val_accuracy: 0.5453
# Epoch 19/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3362 - accuracy: 0.4877
# Epoch 00019: val_accuracy did not improve from 0.54531
# 225/225 [==============================] - 52s 231ms/step - loss: 1.3362 - accuracy: 0.4877 - val_loss: 1.2191 - val_accuracy: 0.5364
# Epoch 20/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3205 - accuracy: 0.4907
# Epoch 00020: val_accuracy improved from 0.54531 to 0.56023, saving model to model_weights.h5
# 225/225 [==============================] - 49s 217ms/step - loss: 1.3205 - accuracy: 0.4907 - val_loss: 1.1672 - val_accuracy: 0.5602
# Epoch 21/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3044 - accuracy: 0.4983
# Epoch 00021: val_accuracy did not improve from 0.56023
# 225/225 [==============================] - 42s 188ms/step - loss: 1.3044 - accuracy: 0.4983 - val_loss: 1.1729 - val_accuracy: 0.5570
# Epoch 22/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2861 - accuracy: 0.5083
# Epoch 00022: val_accuracy did not improve from 0.56023
# 225/225 [==============================] - 42s 188ms/step - loss: 1.2861 - accuracy: 0.5083 - val_loss: 1.2530 - val_accuracy: 0.5250
# Epoch 23/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2811 - accuracy: 0.5087
# Epoch 00023: val_accuracy did not improve from 0.56023
# 225/225 [==============================] - 42s 188ms/step - loss: 1.2811 - accuracy: 0.5087 - val_loss: 1.1728 - val_accuracy: 0.5561
# Epoch 24/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2612 - accuracy: 0.5172
# Epoch 00024: val_accuracy improved from 0.56023 to 0.57557, saving model to model_weights.h5
# 225/225 [==============================] - 42s 186ms/step - loss: 1.2612 - accuracy: 0.5172 - val_loss: 1.1233 - val_accuracy: 0.5756
# Epoch 25/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2505 - accuracy: 0.5198
# Epoch 00025: val_accuracy improved from 0.57557 to 0.57614, saving model to model_weights.h5
# 225/225 [==============================] - 47s 209ms/step - loss: 1.2505 - accuracy: 0.5198 - val_loss: 1.1276 - val_accuracy: 0.5761
# Epoch 26/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2404 - accuracy: 0.5251
# Epoch 00026: val_accuracy did not improve from 0.57614
# 225/225 [==============================] - 59s 263ms/step - loss: 1.2404 - accuracy: 0.5251 - val_loss: 1.1538 - val_accuracy: 0.5641
# Epoch 27/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2297 - accuracy: 0.5324
# Epoch 00027: val_accuracy did not improve from 0.57614
# 225/225 [==============================] - 42s 186ms/step - loss: 1.2297 - accuracy: 0.5324 - val_loss: 1.1566 - val_accuracy: 0.5598
# Epoch 28/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2183 - accuracy: 0.5324
# Epoch 00028: val_accuracy improved from 0.57614 to 0.58182, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.2183 - accuracy: 0.5324 - val_loss: 1.1145 - val_accuracy: 0.5818
# Epoch 29/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2109 - accuracy: 0.5373
# Epoch 00029: val_accuracy did not improve from 0.58182
# 225/225 [==============================] - 42s 187ms/step - loss: 1.2109 - accuracy: 0.5373 - val_loss: 1.1367 - val_accuracy: 0.5693
# Epoch 30/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1973 - accuracy: 0.5433
# Epoch 00030: val_accuracy did not improve from 0.58182
# 225/225 [==============================] - 42s 188ms/step - loss: 1.1973 - accuracy: 0.5433 - val_loss: 1.3228 - val_accuracy: 0.5111
# Epoch 31/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1915 - accuracy: 0.5462
# Epoch 00031: val_accuracy improved from 0.58182 to 0.58835, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.1915 - accuracy: 0.5462 - val_loss: 1.0902 - val_accuracy: 0.5884
# Epoch 32/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1760 - accuracy: 0.5495
# Epoch 00032: val_accuracy did not improve from 0.58835
# 225/225 [==============================] - 42s 186ms/step - loss: 1.1760 - accuracy: 0.5495 - val_loss: 1.1686 - val_accuracy: 0.5506
# Epoch 33/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1733 - accuracy: 0.5529
# Epoch 00033: val_accuracy did not improve from 0.58835
# 225/225 [==============================] - 43s 190ms/step - loss: 1.1733 - accuracy: 0.5529 - val_loss: 1.1086 - val_accuracy: 0.5801
# Epoch 34/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1695 - accuracy: 0.5565
# Epoch 00034: val_accuracy improved from 0.58835 to 0.60085, saving model to model_weights.h5
# 225/225 [==============================] - 43s 189ms/step - loss: 1.1695 - accuracy: 0.5565 - val_loss: 1.0615 - val_accuracy: 0.6009
# Epoch 35/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1612 - accuracy: 0.5549
# Epoch 00035: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 41s 184ms/step - loss: 1.1612 - accuracy: 0.5549 - val_loss: 1.0804 - val_accuracy: 0.5909
# Epoch 36/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1520 - accuracy: 0.5623
# Epoch 00036: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 43s 189ms/step - loss: 1.1520 - accuracy: 0.5623 - val_loss: 1.1008 - val_accuracy: 0.5895
# Epoch 37/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1433 - accuracy: 0.5642
# Epoch 00037: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 46s 204ms/step - loss: 1.1433 - accuracy: 0.5642 - val_loss: 1.0797 - val_accuracy: 0.5892
# Epoch 38/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1384 - accuracy: 0.5660
# Epoch 00038: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 44s 196ms/step - loss: 1.1384 - accuracy: 0.5660 - val_loss: 1.1238 - val_accuracy: 0.5716
# Epoch 39/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1297 - accuracy: 0.5668
# Epoch 00039: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 44s 194ms/step - loss: 1.1297 - accuracy: 0.5668 - val_loss: 1.0622 - val_accuracy: 0.5983
# Epoch 40/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1228 - accuracy: 0.5692
# Epoch 00040: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 44s 195ms/step - loss: 1.1228 - accuracy: 0.5692 - val_loss: 1.0760 - val_accuracy: 0.5945
# Epoch 41/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1201 - accuracy: 0.5737
# Epoch 00041: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 42s 187ms/step - loss: 1.1201 - accuracy: 0.5737 - val_loss: 1.0599 - val_accuracy: 0.5990
# Epoch 42/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1124 - accuracy: 0.5758
# Epoch 00042: val_accuracy improved from 0.60085 to 0.60952, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.1124 - accuracy: 0.5758 - val_loss: 1.0435 - val_accuracy: 0.6095
# Epoch 43/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1078 - accuracy: 0.5796
# Epoch 00043: val_accuracy did not improve from 0.60952
# 225/225 [==============================] - 48s 213ms/step - loss: 1.1078 - accuracy: 0.5796 - val_loss: 1.0760 - val_accuracy: 0.5943
# Epoch 44/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0983 - accuracy: 0.5827
# Epoch 00044: val_accuracy did not improve from 0.60952
# 225/225 [==============================] - 42s 187ms/step - loss: 1.0983 - accuracy: 0.5827 - val_loss: 1.0437 - val_accuracy: 0.6062
# Epoch 45/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0996 - accuracy: 0.5829
# Epoch 00045: val_accuracy did not improve from 0.60952
# 225/225 [==============================] - 42s 186ms/step - loss: 1.0996 - accuracy: 0.5829 - val_loss: 1.0512 - val_accuracy: 0.6041
# Epoch 46/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0866 - accuracy: 0.5875
# Epoch 00046: val_accuracy did not improve from 0.60952
# 225/225 [==============================] - 40s 180ms/step - loss: 1.0866 - accuracy: 0.5875 - val_loss: 1.0724 - val_accuracy: 0.5967
# Epoch 47/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0819 - accuracy: 0.5917
# Epoch 00047: val_accuracy improved from 0.60952 to 0.61151, saving model to model_weights.h5
# 225/225 [==============================] - 41s 181ms/step - loss: 1.0819 - accuracy: 0.5917 - val_loss: 1.0297 - val_accuracy: 0.6115
# Epoch 48/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0764 - accuracy: 0.5900
# Epoch 00048: val_accuracy improved from 0.61151 to 0.61662, saving model to model_weights.h5
# 225/225 [==============================] - 50s 224ms/step - loss: 1.0764 - accuracy: 0.5900 - val_loss: 1.0208 - val_accuracy: 0.6166
# Epoch 49/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0698 - accuracy: 0.5954
# Epoch 00049: val_accuracy did not improve from 0.61662
# 225/225 [==============================] - 40s 180ms/step - loss: 1.0698 - accuracy: 0.5954 - val_loss: 1.0350 - val_accuracy: 0.6092
# Epoch 50/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0670 - accuracy: 0.5942
# Epoch 00050: val_accuracy did not improve from 0.61662
# 225/225 [==============================] - 41s 182ms/step - loss: 1.0670 - accuracy: 0.5942 - val_loss: 1.0372 - val_accuracy: 0.6036
# CPU times: user 23min 8s, sys: 2min 12s, total: 25min 20s
# Wall time: 39min 56s

# %%
# visualise training and testing accuracy and loss

def plot_results(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    


    plt.subplot(1,2,2)
    plt.plot(epochs, loss, 'b', label = 'Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()
 
# print best epoch with best accuracy on validation

def get_best_epcoh(history):
    valid_acc = history.history['val_accuracy']
    best_epoch = valid_acc.index(max(valid_acc)) + 1
    best_acc =  max(valid_acc)
    print('Best Validation Accuracy Score {:0.5f}, is for epoch {}'.format( best_acc, best_epoch))
    return best_epoch

# %%
plot_results(history)
best_epoch =get_best_epcoh(history)
# Out:
# Best Validation Accuracy Score 0.61662, is for epoch 48
